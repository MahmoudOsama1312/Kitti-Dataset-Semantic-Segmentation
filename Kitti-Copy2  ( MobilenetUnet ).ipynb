# %%
import os
import numpy as np
from keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Load Your Data :

# %%
## reading and storing data
IMG_WIDTH=256
IMG_HEIGHT=256
NO_CHANNELS=3

training = 'training' 
train_imgs = training +"/image_2"
train_labels = training +'/semantic_rgb'         # Path of the Labels Images ( Masks )


test = "testing/image_2"

xtrain_ids = os.listdir(os.path.join(train_imgs))          # to read the images ids
ytrain_ids =os.listdir(os.path.join(train_labels))


test_ids = os.listdir(os.path.join(test))

# %%
print('Number of train frames: ' + str(len(os.listdir(train_imgs))))
print('Number of train labels: ' + str(len(os.listdir(train_labels))))

print('Number of test frames: ' + str(len(os.listdir(test))))

print('Total frames: ' + str(len(os.listdir(train_imgs)) + len(os.listdir(train_labels)) + len(os.listdir(test))))
# Out:
# Number of train frames: 200
# Number of train labels: 200
# Number of test frames: 200
# Total frames: 600

# %% [markdown]
# ## Adjust Mask :

# %%
def adjust_mask(mask, flat=False):
    
    semantic_map = []
    for colour in list(cls2rgb.values()):  # values bte3et el classes el fel dictionary
        
        equality = np.equal(mask, colour)          # 256x256x3 with True or False
        class_map = np.all(equality, axis = -1)     # 256x256 If all True, then True, else False
        semantic_map.append(class_map) # List of 256x256 arrays, map of True for a given found color at the pixel, and False otherwise.
    semantic_map = np.stack(semantic_map, axis=-1)   # 256x256x32 True only at the found color, and all False otherwise.
    if flat:
        semantic_map = np.reshape(semantic_map, (-1,256*256))

    return np.float32(semantic_map)# convert to numbers

# %%
import pandas as pd
classes = pd.read_csv('classes.csv', index_col =0)

classes
# Out:
#                         0    1    2
# unlabeled               0    0    0
# ego vehicle             0    0    0
# rectification border    0    0    0
# out of roi              0    0    0
# static                  0    0    0
# dynamic               111   74    0
# ground                 81    0   81
# road                  128   64  128
# sidewalk              244   35  232
# parking               250  170  160
# rail track            230  150  140
# building               70   70   70
# wall                  102  102  156
# fence                 190  153  153
# guard rail            180  165  180
# bridge                150  100  100
# tunnel                150  120   90
# pole                  153  153  153
# polegroup             153  153  153
# traffic light         250  170   30
# traffic sign          220  220    0
# vegetation            107  142   35
# terrain               152  251  152
# sky                    70  130  180
# person                220   20   60
# rider                 255    0    0
# car                     0    0  142
# truck                   0    0   70
# bus                     0   60  100
# caravan                 0    0   90
# trailer                 0    0  110
# train                   0   80  100
# motorcycle              0    0  230
# bicycle               119   11   32
# license plate           0    0  142

# %%
n_classes= len(classes)
print(n_classes)
# Out:
# 35

# %%
cls2rgb = {cl:list(classes.loc[cl, :]) for cl in classes.index}

# %%
cls2rgb
# Out:
# {'unlabeled': [0, 0, 0],
#  'ego vehicle': [0, 0, 0],
#  'rectification border': [0, 0, 0],
#  'out of roi': [0, 0, 0],
#  'static': [0, 0, 0],
#  'dynamic': [111, 74, 0],
#  'ground': [81, 0, 81],
#  'road': [128, 64, 128],
#  'sidewalk': [244, 35, 232],
#  'parking': [250, 170, 160],
#  'rail track': [230, 150, 140],
#  'building': [70, 70, 70],
#  'wall': [102, 102, 156],
#  'fence': [190, 153, 153],
#  'guard rail': [180, 165, 180],
#  'bridge': [150, 100, 100],
#  'tunnel': [150, 120, 90],
#  'pole': [153, 153, 153],
#  'polegroup': [153, 153, 153],
#  'traffic light': [250, 170, 30],
#  'traffic sign': [220, 220, 0],
#  'vegetation': [107, 142, 35],
#  'terrain': [152, 251, 152],
#  'sky': [70, 130, 180],
#  'person': [220, 20, 60],
#  'rider': [255, 0, 0],
#  'car': [0, 0, 142],
#  'truck': [0, 0, 70],
#  'bus': [0, 60, 100],
#  'caravan': [0, 0, 90],
#  'trailer': [0, 0, 110],
#  'train': [0, 80, 100],
#  'motorcycle': [0, 0, 230],
#  'bicycle': [119, 11, 32],
#  'license plate': [0, 0, 142]}

# %% [markdown]
# ## Now let's visualize and explore some samples:

# %%
from keras.preprocessing import image     
import cv2
import matplotlib.pyplot as plt


img = image.load_img(train_imgs+ "/000000_10.png")
plt.imshow(img)

# %% [markdown]
# ## Let's have a look on the masks (the ground truth)  ( Labels )

# %%
mask  = image.load_img(train_labels+ "/000000_10.png")
plt.imshow(mask)

# %%
import numpy as np
mask = np.array(mask)# Now colors are the same as in the dict, since keras load_img uses RGB order.
mask.shape
# Out:
# (375, 1242, 3)

# %%
new_mask = adjust_mask(mask)

# %%
new_mask.shape
# Out:
# (375, 1242, 35)

# %%
idx2rgb={idx:np.array(rgb) for idx, (cl, rgb) in enumerate(cls2rgb.items())}
idx2rgb
# Out:
# {0: array([0, 0, 0]),
#  1: array([0, 0, 0]),
#  2: array([0, 0, 0]),
#  3: array([0, 0, 0]),
#  4: array([0, 0, 0]),
#  5: array([111,  74,   0]),
#  6: array([81,  0, 81]),
#  7: array([128,  64, 128]),
#  8: array([244,  35, 232]),
#  9: array([250, 170, 160]),
#  10: array([230, 150, 140]),
#  11: array([70, 70, 70]),
#  12: array([102, 102, 156]),
#  13: array([190, 153, 153]),
#  14: array([180, 165, 180]),
#  15: array([150, 100, 100]),
#  16: array([150, 120,  90]),
#  17: array([153, 153, 153]),
#  18: array([153, 153, 153]),
#  19: array([250, 170,  30]),
#  20: array([220, 220,   0]),
#  21: array([107, 142,  35]),
#  22: array([152, 251, 152]),
#  23: array([ 70, 130, 180]),
#  24: array([220,  20,  60]),
#  25: array([255,   0,   0]),
#  26: array([  0,   0, 142]),
#  27: array([ 0,  0, 70]),
#  28: array([  0,  60, 100]),
#  29: array([ 0,  0, 90]),
#  30: array([  0,   0, 110]),
#  31: array([  0,  80, 100]),
#  32: array([  0,   0, 230]),
#  33: array([119,  11,  32]),
#  34: array([  0,   0, 142])}

# %% [markdown]
# ## To Convert the mask Back   from 32 channels  to 3 channels only like the original

# %%
# Map the idx back to rgb          # Hena  3lsh 
def map_class_to_rgb(p):
  
  return idx2rgb[p[0]]

rgb_mask = np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(np.argmax(new_mask, axis=-1), -1))  

## -1 means 3adad el masks kolha

# %%
plt.imshow(rgb_mask)

# %%
import numpy as np 
import os
from tensorflow.keras.applications import MobileNetV2
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
IMAGE_SIZE =256

def mob_unet_model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)
    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    
    f = [16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(n_classes, (1, 1), padding="same")(x)
    x = Activation("softmax")(x)
    
    model = Model(inputs, x)
    return model

# %%
model = mob_unet_model()
LR= 1e-4
iou = tf.keras.metrics.MeanIoU(n_classes, name=None, dtype=None)
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(LR), metrics=[iou,"accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 256, 256, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 128, 128, 16  432         ['input_image[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 128, 128, 16  64          ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 128, 128, 16  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 128, 128, 16  144        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 128, 128, 16  64         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 128, 128, 16  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 128, 128, 8)  128        ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 128, 128, 8)  32         ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 128, 128, 48  384         ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 128, 128, 48  192        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 128, 128, 48  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 129, 129, 48  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 64, 64, 48)  432         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 64, 64, 48)  192         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 64, 64, 48)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 64, 64, 8)    384         ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 64, 64, 8)   32          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 64, 64, 48)   384         ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 64, 64, 48)  192         ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 64, 64, 48)   0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 64, 64, 48)  432         ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 64, 64, 48)  192         ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 64, 64, 48)   0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 64, 64, 8)    384         ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 64, 64, 8)   32          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 64, 64, 8)    0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 64, 64, 48)   384         ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 64, 64, 48)  192         ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 64, 64, 48)   0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 65, 65, 48)   0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 32, 32, 48)  432         ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 32, 32, 48)  192         ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 32, 32, 48)   0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 32, 32, 16)   768         ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 32, 32, 16)  64          ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 32, 32, 96)   1536        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 32, 32, 96)  384         ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 32, 32, 96)   0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 32, 32, 96)  864         ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 32, 32, 96)  384         ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 32, 32, 96)   0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 32, 32, 16)   1536        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 32, 32, 16)  64          ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 32, 32, 16)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 32, 32, 96)   1536        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 32, 32, 96)  384         ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 32, 32, 96)   0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 32, 32, 96)  864         ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 32, 32, 96)  384         ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 32, 32, 96)   0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 32, 32, 16)   1536        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 32, 32, 16)  64          ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 32, 32, 16)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 32, 32, 96)   1536        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 32, 32, 96)  384         ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 32, 32, 96)   0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 33, 33, 96)   0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 16, 16, 96)  864         ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 16, 16, 96)  384         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 16, 16, 96)   0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 16, 16, 24)   2304        ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 16, 16, 24)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 16, 16, 24)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 16, 16, 24)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 16, 16, 144)  3456        ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 16, 16, 144)  576        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 16, 16, 144)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 16, 16, 144)  1296       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 16, 16, 144)  576        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 16, 16, 144)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 16, 16, 32)   4608        ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 16, 16, 32)  128         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 16, 16, 192)  6144        ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 16, 16, 192)  768        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 16, 16, 192)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 16, 16, 192)  1728       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 16, 16, 192)  768        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 16, 16, 192)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 16, 16, 32)   6144        ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 16, 16, 32)  128         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 16, 16, 32)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 16, 16, 192)  6144        ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 16, 16, 192)  768        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 16, 16, 192)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 16, 16, 192)  1728       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 16, 16, 192)  768        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 16, 16, 192)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 16, 16, 32)   6144        ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 16, 16, 32)  128         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 16, 16, 32)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 16, 16, 192)  6144        ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 16, 16, 192)  768        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 16, 16, 192)  0           ['block_13_expand_BN[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 192)  0           ['block_13_expand_relu[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 288)  0           ['up_sampling2d[0][0]',
#                                                                   'block_6_expand_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   165952      ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 64)   36928       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_1[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 64)  0           ['activation_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 112)  0           ['up_sampling2d_1[0][0]',
#                                                                   'block_3_expand_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 48)   48432       ['concatenate_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 48)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 48)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 48)   20784       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 48)  192         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 48)   0           ['batch_normalization_3[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 48  0          ['activation_3[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_2[0][0]',
#                                 )                                 'block_1_expand_relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  27680       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  9248        ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 32  0          ['activation_5[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 35  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'input_image[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 16  5056        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 16  64         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 16  2320        ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 16  64         ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 35  595         ['activation_7[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 256, 256, 35  0           ['conv2d_8[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 416,787
# Trainable params: 409,603
# Non-trainable params: 7,184
# __________________________________________________________________________________________________

# %% [markdown]
# ## Loading Train Data :

# %%
from keras.preprocessing.image import load_img
def load_raw_CAMVID(data_type='training', enc='ohe', shape='normal'):
    img_path = data_type + '/image_2'+ "/"
    labels_path = data_type + '/semantic_rgb/'
  # without adding target_size=(256,256) in load_img we get Out of mem: 421x960x720x32x4bytes is around 34GB!
    x = np.array([np.array(load_img(str(img_path) + file, target_size=(256,256)))*1./255 for file in sorted(os.listdir(img_path))])
    
    if(enc=='ohe'):
    
        y = np.array([np.array(load_img(str(labels_path) + file, target_size=(256,256))) for file in sorted(os.listdir(labels_path))])
    return x, y

## Notee : we did do the adjust Mask Here on ( y ) because we will do it in the Generator function

# %%
import time
start = time.time()
X_train, Y_train = load_raw_CAMVID(data_type='training')           # load camvid returns x , y  , x for xTrain , y for yTrain


end = time.time()
print('Time elapsed: ', end-start)
# Out:
# Time elapsed:  2.849273920059204

# %% [markdown]
# ## Split the Training Dataa  to Train - Validation

# %%
from sklearn.model_selection import train_test_split
X_train, X_val , Y_train , Y_val =  train_test_split(X_train,
                                                 Y_train,
                                                test_size=0.1,
                                                random_state = 42)

# %%
print(X_train.shape)
print(Y_train.shape)

print(X_val.shape)
print(Y_val.shape)
# Out:
# (180, 256, 256, 3)
# (180, 256, 256, 3)
# (20, 256, 256, 3)
# (20, 256, 256, 3)

# %% [markdown]
# ## Loading Test Data

# %%
from keras.preprocessing.image import load_img
def load_raw_CAMVID(data_type='testing', enc='ohe', shape='normal'):
    img_path = data_type + '/image_2/'
  # without adding target_size=(256,256) in load_img we get Out of mem: 421x960x720x32x4bytes is around 34GB!
    x = np.array([np.array(load_img(str(img_path) + file, target_size=(256,256)))*1./255 for file in sorted(os.listdir(img_path))])
    
    return x

## Notee : we did do the adjust Mask Here on ( y ) because we will do it in the Generator function

# %%
start = time.time()
X_test = load_raw_CAMVID(data_type='testing')  
end = time.time()
print('Time elapsed: ', end-start)
# Out:
# Time elapsed:  1.8830692768096924

# %% [markdown]
# ## -----------#############_----------Data Augmantation ------------######

# %% [markdown]
# ## for training :

# %%
# Data generator
batch_sz = 4
#https://keras.io/preprocessing/image/
from keras.preprocessing.image import ImageDataGenerator
# we create two instances with the same arguments

# VI Note: use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
                    #rescale=1./255)# Data is already scaled when loaded

mask_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
                    #preprocessing_function=adjust_mask)# This is not possible since the preprocessing_function can only return the same shape as image

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen  = ImageDataGenerator(**mask_gen_args) 

# Provide the same seed and keyword arguments to the fit and flow methods
seed = 1
#image_datagen.fit(images, augment=True, seed=seed)
#mask_datagen.fit(masks, augment=True, seed=seed)

image_generator = image_datagen.flow(
    X_train,
    seed=seed,
    batch_size=batch_sz)

mask_generator = mask_datagen.flow( 
    Y_train,
    seed=seed,
    batch_size=batch_sz)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %%
def train_generator_fn():

    for (img,mask) in train_generator:
        new_mask = adjust_mask(mask)
        yield (img,new_mask)  
        
val_image_generator = image_datagen.flow(
    X_val,
    seed=seed,
    batch_size=batch_sz)

val_mask_generator = mask_datagen.flow(
    Y_val,
    seed=seed,
    batch_size=batch_sz)

# combine generators into one which yields image and masks
val_generator = zip(val_image_generator, val_mask_generator)        
        
def val_generator_fn():

    for (img,mask) in val_generator:
        new_mask = adjust_mask(mask)
        yield (img,new_mask)

# %%
view = 0
batch_sz = 4
epochs = 7
steps_per_epoch = 120
validation_steps = 30

# %%
from keras.callbacks import ReduceLROnPlateau ,EarlyStopping ,ModelCheckpoint
reduce_lr = ReduceLROnPlateau(
    monitor = "val_accuracy", 
    patience = 40,
    verbose = 1, 
    factor = 0.5, 
    min_lr = 0.000000001
)

early_stopping = EarlyStopping(
    monitor = "val_accuracy",
    patience = 5,
    verbose = 1,
    mode = "max",
)

checkpoint = ModelCheckpoint(
    monitor = "val_loss",
    filepath = "MobileUnet.hdf5",
    verbose = 1,
    save_best_only = True, 
    save_weights_only = True
)
callbacks= [reduce_lr,checkpoint]

# %%
model.fit_generator(train_generator_fn(),
                    validation_data=val_generator_fn(),
                    steps_per_epoch=len(X_train)//batch_sz,
                    validation_steps=len(X_val)//batch_sz,
                    epochs=200,
                    callbacks=callbacks)
# Out:
# <ipython-input-29-0e8a4cb0fea8>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator_fn(),
# Epoch 1/200
# 45/45 [==============================] - ETA: 0s - loss: 3.5346 - mean_io_u: 0.4852 - accuracy: 0.1184
# Epoch 00001: val_accuracy improved from -inf to 0.06677, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 21s 310ms/step - loss: 3.5346 - mean_io_u: 0.4852 - accuracy: 0.1184 - val_loss: 3.5941 - val_mean_io_u: 0.4852 - val_accuracy: 0.0668 - lr: 1.0000e-04
# Epoch 2/200
# 45/45 [==============================] - ETA: 0s - loss: 3.1282 - mean_io_u: 0.4852 - accuracy: 0.3501
# Epoch 00002: val_accuracy improved from 0.06677 to 0.30689, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 297ms/step - loss: 3.1282 - mean_io_u: 0.4852 - accuracy: 0.3501 - val_loss: 3.2302 - val_mean_io_u: 0.4853 - val_accuracy: 0.3069 - lr: 1.0000e-04
# Epoch 3/200
# 45/45 [==============================] - ETA: 0s - loss: 2.9346 - mean_io_u: 0.4852 - accuracy: 0.5081
# Epoch 00003: val_accuracy improved from 0.30689 to 0.36702, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 300ms/step - loss: 2.9346 - mean_io_u: 0.4852 - accuracy: 0.5081 - val_loss: 3.2713 - val_mean_io_u: 0.4849 - val_accuracy: 0.3670 - lr: 1.0000e-04
# Epoch 4/200
# 45/45 [==============================] - ETA: 0s - loss: 2.8217 - mean_io_u: 0.4852 - accuracy: 0.5428
# Epoch 00004: val_accuracy improved from 0.36702 to 0.39831, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 300ms/step - loss: 2.8217 - mean_io_u: 0.4852 - accuracy: 0.5428 - val_loss: 3.0924 - val_mean_io_u: 0.4853 - val_accuracy: 0.3983 - lr: 1.0000e-04
# Epoch 5/200
# 45/45 [==============================] - ETA: 0s - loss: 2.7290 - mean_io_u: 0.4852 - accuracy: 0.5608
# Epoch 00005: val_accuracy improved from 0.39831 to 0.40275, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 300ms/step - loss: 2.7290 - mean_io_u: 0.4852 - accuracy: 0.5608 - val_loss: 3.1189 - val_mean_io_u: 0.4851 - val_accuracy: 0.4027 - lr: 1.0000e-04
# Epoch 6/200
# 45/45 [==============================] - ETA: 0s - loss: 2.6542 - mean_io_u: 0.4852 - accuracy: 0.5703
# Epoch 00006: val_accuracy improved from 0.40275 to 0.47216, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 301ms/step - loss: 2.6542 - mean_io_u: 0.4852 - accuracy: 0.5703 - val_loss: 3.0368 - val_mean_io_u: 0.4852 - val_accuracy: 0.4722 - lr: 1.0000e-04
# Epoch 7/200
# 45/45 [==============================] - ETA: 0s - loss: 2.5896 - mean_io_u: 0.4852 - accuracy: 0.5853
# Epoch 00007: val_accuracy did not improve from 0.47216
# 45/45 [==============================] - 13s 293ms/step - loss: 2.5896 - mean_io_u: 0.4852 - accuracy: 0.5853 - val_loss: 3.0987 - val_mean_io_u: 0.4854 - val_accuracy: 0.4321 - lr: 1.0000e-04
# Epoch 8/200
# 45/45 [==============================] - ETA: 0s - loss: 2.5126 - mean_io_u: 0.4852 - accuracy: 0.6014
# Epoch 00008: val_accuracy improved from 0.47216 to 0.55698, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 298ms/step - loss: 2.5126 - mean_io_u: 0.4852 - accuracy: 0.6014 - val_loss: 2.8949 - val_mean_io_u: 0.4852 - val_accuracy: 0.5570 - lr: 1.0000e-04
# Epoch 9/200
# 45/45 [==============================] - ETA: 0s - loss: 2.4365 - mean_io_u: 0.4852 - accuracy: 0.6187
# Epoch 00009: val_accuracy did not improve from 0.55698
# 45/45 [==============================] - 13s 294ms/step - loss: 2.4365 - mean_io_u: 0.4852 - accuracy: 0.6187 - val_loss: 2.9526 - val_mean_io_u: 0.4852 - val_accuracy: 0.5261 - lr: 1.0000e-04
# Epoch 10/200
# 45/45 [==============================] - ETA: 0s - loss: 2.3829 - mean_io_u: 0.4852 - accuracy: 0.6438
# Epoch 00010: val_accuracy improved from 0.55698 to 0.58814, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 301ms/step - loss: 2.3829 - mean_io_u: 0.4852 - accuracy: 0.6438 - val_loss: 2.8751 - val_mean_io_u: 0.4850 - val_accuracy: 0.5881 - lr: 1.0000e-04
# Epoch 11/200
# 45/45 [==============================] - ETA: 0s - loss: 2.3206 - mean_io_u: 0.4852 - accuracy: 0.7001
# Epoch 00011: val_accuracy improved from 0.58814 to 0.60777, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 299ms/step - loss: 2.3206 - mean_io_u: 0.4852 - accuracy: 0.7001 - val_loss: 2.7708 - val_mean_io_u: 0.4852 - val_accuracy: 0.6078 - lr: 1.0000e-04
# Epoch 12/200
# 45/45 [==============================] - ETA: 0s - loss: 2.2702 - mean_io_u: 0.4852 - accuracy: 0.7040
# Epoch 00012: val_accuracy did not improve from 0.60777
# 45/45 [==============================] - 13s 295ms/step - loss: 2.2702 - mean_io_u: 0.4852 - accuracy: 0.7040 - val_loss: 2.8002 - val_mean_io_u: 0.4850 - val_accuracy: 0.5920 - lr: 1.0000e-04
# Epoch 13/200
# 45/45 [==============================] - ETA: 0s - loss: 2.2248 - mean_io_u: 0.4852 - accuracy: 0.7077
# Epoch 00013: val_accuracy improved from 0.60777 to 0.65255, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 299ms/step - loss: 2.2248 - mean_io_u: 0.4852 - accuracy: 0.7077 - val_loss: 2.5687 - val_mean_io_u: 0.4854 - val_accuracy: 0.6525 - lr: 1.0000e-04
# Epoch 14/200
# 45/45 [==============================] - ETA: 0s - loss: 2.1597 - mean_io_u: 0.4852 - accuracy: 0.7300
# Epoch 00014: val_accuracy did not improve from 0.65255
# 45/45 [==============================] - 13s 293ms/step - loss: 2.1597 - mean_io_u: 0.4852 - accuracy: 0.7300 - val_loss: 2.5942 - val_mean_io_u: 0.4850 - val_accuracy: 0.6387 - lr: 1.0000e-04
# Epoch 15/200
# 45/45 [==============================] - ETA: 0s - loss: 2.0956 - mean_io_u: 0.4852 - accuracy: 0.7502
# Epoch 00015: val_accuracy did not improve from 0.65255
# 45/45 [==============================] - 13s 293ms/step - loss: 2.0956 - mean_io_u: 0.4852 - accuracy: 0.7502 - val_loss: 2.4876 - val_mean_io_u: 0.4854 - val_accuracy: 0.6426 - lr: 1.0000e-04
# Epoch 16/200
# 45/45 [==============================] - ETA: 0s - loss: 2.0509 - mean_io_u: 0.4852 - accuracy: 0.7464
# Epoch 00016: val_accuracy improved from 0.65255 to 0.68784, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 300ms/step - loss: 2.0509 - mean_io_u: 0.4852 - accuracy: 0.7464 - val_loss: 2.3348 - val_mean_io_u: 0.4852 - val_accuracy: 0.6878 - lr: 1.0000e-04
# Epoch 17/200
# 45/45 [==============================] - ETA: 0s - loss: 2.0112 - mean_io_u: 0.4852 - accuracy: 0.7487
# Epoch 00017: val_accuracy did not improve from 0.68784
# 45/45 [==============================] - 13s 294ms/step - loss: 2.0112 - mean_io_u: 0.4852 - accuracy: 0.7487 - val_loss: 2.4342 - val_mean_io_u: 0.4853 - val_accuracy: 0.6545 - lr: 1.0000e-04
# Epoch 18/200
# 45/45 [==============================] - ETA: 0s - loss: 1.9498 - mean_io_u: 0.4852 - accuracy: 0.7569
# Epoch 00018: val_accuracy improved from 0.68784 to 0.70553, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 298ms/step - loss: 1.9498 - mean_io_u: 0.4852 - accuracy: 0.7569 - val_loss: 2.1467 - val_mean_io_u: 0.4851 - val_accuracy: 0.7055 - lr: 1.0000e-04
# Epoch 19/200
# 45/45 [==============================] - ETA: 0s - loss: 1.9240 - mean_io_u: 0.4852 - accuracy: 0.7521
# Epoch 00019: val_accuracy did not improve from 0.70553
# 45/45 [==============================] - 13s 293ms/step - loss: 1.9240 - mean_io_u: 0.4852 - accuracy: 0.7521 - val_loss: 2.1520 - val_mean_io_u: 0.4851 - val_accuracy: 0.6799 - lr: 1.0000e-04
# Epoch 20/200
# 45/45 [==============================] - ETA: 0s - loss: 1.8594 - mean_io_u: 0.4852 - accuracy: 0.7615
# Epoch 00020: val_accuracy improved from 0.70553 to 0.72778, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 300ms/step - loss: 1.8594 - mean_io_u: 0.4852 - accuracy: 0.7615 - val_loss: 2.0644 - val_mean_io_u: 0.4852 - val_accuracy: 0.7278 - lr: 1.0000e-04
# Epoch 21/200
# 45/45 [==============================] - ETA: 0s - loss: 1.7997 - mean_io_u: 0.4852 - accuracy: 0.7646
# Epoch 00021: val_accuracy did not improve from 0.72778
# 45/45 [==============================] - 13s 296ms/step - loss: 1.7997 - mean_io_u: 0.4852 - accuracy: 0.7646 - val_loss: 1.9944 - val_mean_io_u: 0.4852 - val_accuracy: 0.7108 - lr: 1.0000e-04
# Epoch 22/200
# 45/45 [==============================] - ETA: 0s - loss: 1.7698 - mean_io_u: 0.4852 - accuracy: 0.7638
# Epoch 00022: val_accuracy did not improve from 0.72778
# 45/45 [==============================] - 13s 293ms/step - loss: 1.7698 - mean_io_u: 0.4852 - accuracy: 0.7638 - val_loss: 2.0121 - val_mean_io_u: 0.4849 - val_accuracy: 0.7107 - lr: 1.0000e-04
# Epoch 23/200
# 45/45 [==============================] - ETA: 0s - loss: 1.7291 - mean_io_u: 0.4852 - accuracy: 0.7627
# Epoch 00023: val_accuracy improved from 0.72778 to 0.76189, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 14s 307ms/step - loss: 1.7291 - mean_io_u: 0.4852 - accuracy: 0.7627 - val_loss: 1.8762 - val_mean_io_u: 0.4852 - val_accuracy: 0.7619 - lr: 1.0000e-04
# Epoch 24/200
# 45/45 [==============================] - ETA: 0s - loss: 1.6768 - mean_io_u: 0.4852 - accuracy: 0.7681
# Epoch 00024: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.6768 - mean_io_u: 0.4852 - accuracy: 0.7681 - val_loss: 1.8652 - val_mean_io_u: 0.4856 - val_accuracy: 0.7213 - lr: 1.0000e-04
# Epoch 25/200
# 45/45 [==============================] - ETA: 0s - loss: 1.6329 - mean_io_u: 0.4852 - accuracy: 0.7714
# Epoch 00025: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.6329 - mean_io_u: 0.4852 - accuracy: 0.7714 - val_loss: 1.8483 - val_mean_io_u: 0.4853 - val_accuracy: 0.7239 - lr: 1.0000e-04
# Epoch 26/200
# 45/45 [==============================] - ETA: 0s - loss: 1.6065 - mean_io_u: 0.4852 - accuracy: 0.7704
# Epoch 00026: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 297ms/step - loss: 1.6065 - mean_io_u: 0.4852 - accuracy: 0.7704 - val_loss: 1.8404 - val_mean_io_u: 0.4852 - val_accuracy: 0.7370 - lr: 1.0000e-04
# Epoch 27/200
# 45/45 [==============================] - ETA: 0s - loss: 1.5689 - mean_io_u: 0.4852 - accuracy: 0.7721
# Epoch 00027: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 298ms/step - loss: 1.5689 - mean_io_u: 0.4852 - accuracy: 0.7721 - val_loss: 1.7498 - val_mean_io_u: 0.4852 - val_accuracy: 0.7287 - lr: 1.0000e-04
# Epoch 28/200
# 45/45 [==============================] - ETA: 0s - loss: 1.5494 - mean_io_u: 0.4852 - accuracy: 0.7704
# Epoch 00028: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.5494 - mean_io_u: 0.4852 - accuracy: 0.7704 - val_loss: 1.7842 - val_mean_io_u: 0.4850 - val_accuracy: 0.7335 - lr: 1.0000e-04
# Epoch 29/200
# 45/45 [==============================] - ETA: 0s - loss: 1.4944 - mean_io_u: 0.4852 - accuracy: 0.7742
# Epoch 00029: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.4944 - mean_io_u: 0.4852 - accuracy: 0.7742 - val_loss: 1.6863 - val_mean_io_u: 0.4851 - val_accuracy: 0.7542 - lr: 1.0000e-04
# Epoch 30/200
# 45/45 [==============================] - ETA: 0s - loss: 1.4521 - mean_io_u: 0.4852 - accuracy: 0.7785
# Epoch 00030: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.4521 - mean_io_u: 0.4852 - accuracy: 0.7785 - val_loss: 1.6675 - val_mean_io_u: 0.4852 - val_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 31/200
# 45/45 [==============================] - ETA: 0s - loss: 1.4261 - mean_io_u: 0.4853 - accuracy: 0.7781
# Epoch 00031: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.4261 - mean_io_u: 0.4853 - accuracy: 0.7781 - val_loss: 1.7082 - val_mean_io_u: 0.4852 - val_accuracy: 0.7126 - lr: 1.0000e-04
# Epoch 32/200
# 45/45 [==============================] - ETA: 0s - loss: 1.3907 - mean_io_u: 0.4852 - accuracy: 0.7806
# Epoch 00032: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 303ms/step - loss: 1.3907 - mean_io_u: 0.4852 - accuracy: 0.7806 - val_loss: 1.7280 - val_mean_io_u: 0.4851 - val_accuracy: 0.7104 - lr: 1.0000e-04
# Epoch 33/200
# 45/45 [==============================] - ETA: 0s - loss: 1.3668 - mean_io_u: 0.4852 - accuracy: 0.7795
# Epoch 00033: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 299ms/step - loss: 1.3668 - mean_io_u: 0.4852 - accuracy: 0.7795 - val_loss: 1.5781 - val_mean_io_u: 0.4853 - val_accuracy: 0.7404 - lr: 1.0000e-04
# Epoch 34/200
# 45/45 [==============================] - ETA: 0s - loss: 1.3414 - mean_io_u: 0.4852 - accuracy: 0.7817
# Epoch 00034: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 295ms/step - loss: 1.3414 - mean_io_u: 0.4852 - accuracy: 0.7817 - val_loss: 1.5739 - val_mean_io_u: 0.4852 - val_accuracy: 0.7328 - lr: 1.0000e-04
# Epoch 35/200
# 45/45 [==============================] - ETA: 0s - loss: 1.3361 - mean_io_u: 0.4852 - accuracy: 0.7758
# Epoch 00035: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.3361 - mean_io_u: 0.4852 - accuracy: 0.7758 - val_loss: 1.6092 - val_mean_io_u: 0.4848 - val_accuracy: 0.7447 - lr: 1.0000e-04
# Epoch 36/200
# 45/45 [==============================] - ETA: 0s - loss: 1.3149 - mean_io_u: 0.4852 - accuracy: 0.7775
# Epoch 00036: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.3149 - mean_io_u: 0.4852 - accuracy: 0.7775 - val_loss: 1.4703 - val_mean_io_u: 0.4851 - val_accuracy: 0.7437 - lr: 1.0000e-04
# Epoch 37/200
# 45/45 [==============================] - ETA: 0s - loss: 1.2721 - mean_io_u: 0.4852 - accuracy: 0.7812
# Epoch 00037: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 297ms/step - loss: 1.2721 - mean_io_u: 0.4852 - accuracy: 0.7812 - val_loss: 1.4596 - val_mean_io_u: 0.4852 - val_accuracy: 0.7565 - lr: 1.0000e-04
# Epoch 38/200
# 45/45 [==============================] - ETA: 0s - loss: 1.2623 - mean_io_u: 0.4853 - accuracy: 0.7799
# Epoch 00038: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.2623 - mean_io_u: 0.4853 - accuracy: 0.7799 - val_loss: 1.5446 - val_mean_io_u: 0.4851 - val_accuracy: 0.7249 - lr: 1.0000e-04
# Epoch 39/200
# 45/45 [==============================] - ETA: 0s - loss: 1.2261 - mean_io_u: 0.4852 - accuracy: 0.7831
# Epoch 00039: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.2261 - mean_io_u: 0.4852 - accuracy: 0.7831 - val_loss: 1.5363 - val_mean_io_u: 0.4849 - val_accuracy: 0.7390 - lr: 1.0000e-04
# Epoch 40/200
# 45/45 [==============================] - ETA: 0s - loss: 1.2031 - mean_io_u: 0.4852 - accuracy: 0.7850
# Epoch 00040: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 296ms/step - loss: 1.2031 - mean_io_u: 0.4852 - accuracy: 0.7850 - val_loss: 1.4394 - val_mean_io_u: 0.4852 - val_accuracy: 0.7476 - lr: 1.0000e-04
# Epoch 41/200
# 45/45 [==============================] - ETA: 0s - loss: 1.1820 - mean_io_u: 0.4852 - accuracy: 0.7867
# Epoch 00041: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.1820 - mean_io_u: 0.4852 - accuracy: 0.7867 - val_loss: 1.4529 - val_mean_io_u: 0.4851 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 42/200
# 45/45 [==============================] - ETA: 0s - loss: 1.1672 - mean_io_u: 0.4852 - accuracy: 0.7863
# Epoch 00042: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.1672 - mean_io_u: 0.4852 - accuracy: 0.7863 - val_loss: 1.3478 - val_mean_io_u: 0.4851 - val_accuracy: 0.7431 - lr: 1.0000e-04
# Epoch 43/200
# 45/45 [==============================] - ETA: 0s - loss: 1.1591 - mean_io_u: 0.4852 - accuracy: 0.7831
# Epoch 00043: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 294ms/step - loss: 1.1591 - mean_io_u: 0.4852 - accuracy: 0.7831 - val_loss: 1.2843 - val_mean_io_u: 0.4855 - val_accuracy: 0.7488 - lr: 1.0000e-04
# Epoch 44/200
# 45/45 [==============================] - ETA: 0s - loss: 1.1216 - mean_io_u: 0.4852 - accuracy: 0.7884
# Epoch 00044: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.1216 - mean_io_u: 0.4852 - accuracy: 0.7884 - val_loss: 1.4296 - val_mean_io_u: 0.4852 - val_accuracy: 0.7076 - lr: 1.0000e-04
# Epoch 45/200
# 45/45 [==============================] - ETA: 0s - loss: 1.1116 - mean_io_u: 0.4853 - accuracy: 0.7872
# Epoch 00045: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.1116 - mean_io_u: 0.4853 - accuracy: 0.7872 - val_loss: 1.3719 - val_mean_io_u: 0.4850 - val_accuracy: 0.7501 - lr: 1.0000e-04
# Epoch 46/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0853 - mean_io_u: 0.4853 - accuracy: 0.7901
# Epoch 00046: val_accuracy did not improve from 0.76189
# 45/45 [==============================] - 13s 293ms/step - loss: 1.0853 - mean_io_u: 0.4853 - accuracy: 0.7901 - val_loss: 1.3208 - val_mean_io_u: 0.4852 - val_accuracy: 0.7431 - lr: 1.0000e-04
# Epoch 47/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0870 - mean_io_u: 0.4852 - accuracy: 0.7877
# Epoch 00047: val_accuracy improved from 0.76189 to 0.76866, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 299ms/step - loss: 1.0870 - mean_io_u: 0.4852 - accuracy: 0.7877 - val_loss: 1.1551 - val_mean_io_u: 0.4855 - val_accuracy: 0.7687 - lr: 1.0000e-04
# Epoch 48/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0626 - mean_io_u: 0.4852 - accuracy: 0.7898
# Epoch 00048: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 297ms/step - loss: 1.0626 - mean_io_u: 0.4852 - accuracy: 0.7898 - val_loss: 1.3441 - val_mean_io_u: 0.4851 - val_accuracy: 0.7298 - lr: 1.0000e-04
# Epoch 49/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0475 - mean_io_u: 0.4852 - accuracy: 0.7911
# Epoch 00049: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 298ms/step - loss: 1.0475 - mean_io_u: 0.4852 - accuracy: 0.7911 - val_loss: 1.1608 - val_mean_io_u: 0.4853 - val_accuracy: 0.7582 - lr: 1.0000e-04
# Epoch 50/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0423 - mean_io_u: 0.4852 - accuracy: 0.7884
# Epoch 00050: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 299ms/step - loss: 1.0423 - mean_io_u: 0.4852 - accuracy: 0.7884 - val_loss: 1.2424 - val_mean_io_u: 0.4854 - val_accuracy: 0.7246 - lr: 1.0000e-04
# Epoch 51/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0301 - mean_io_u: 0.4852 - accuracy: 0.7900
# Epoch 00051: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 295ms/step - loss: 1.0301 - mean_io_u: 0.4852 - accuracy: 0.7900 - val_loss: 1.2701 - val_mean_io_u: 0.4851 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 52/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0064 - mean_io_u: 0.4853 - accuracy: 0.7916
# Epoch 00052: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 294ms/step - loss: 1.0064 - mean_io_u: 0.4853 - accuracy: 0.7916 - val_loss: 1.2018 - val_mean_io_u: 0.4851 - val_accuracy: 0.7483 - lr: 1.0000e-04
# Epoch 53/200
# 45/45 [==============================] - ETA: 0s - loss: 1.0122 - mean_io_u: 0.4852 - accuracy: 0.7895
# Epoch 00053: val_accuracy did not improve from 0.76866
# 45/45 [==============================] - 13s 288ms/step - loss: 1.0122 - mean_io_u: 0.4852 - accuracy: 0.7895 - val_loss: 1.2757 - val_mean_io_u: 0.4850 - val_accuracy: 0.7459 - lr: 1.0000e-04
# Epoch 54/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9915 - mean_io_u: 0.4852 - accuracy: 0.7901
# Epoch 00054: val_accuracy improved from 0.76866 to 0.77894, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.9915 - mean_io_u: 0.4852 - accuracy: 0.7901 - val_loss: 1.1212 - val_mean_io_u: 0.4851 - val_accuracy: 0.7789 - lr: 1.0000e-04
# Epoch 55/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9863 - mean_io_u: 0.4852 - accuracy: 0.7894
# Epoch 00055: val_accuracy did not improve from 0.77894
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9863 - mean_io_u: 0.4852 - accuracy: 0.7894 - val_loss: 1.1452 - val_mean_io_u: 0.4851 - val_accuracy: 0.7570 - lr: 1.0000e-04
# Epoch 56/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9803 - mean_io_u: 0.4852 - accuracy: 0.7887
# Epoch 00056: val_accuracy did not improve from 0.77894
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9803 - mean_io_u: 0.4852 - accuracy: 0.7887 - val_loss: 1.0959 - val_mean_io_u: 0.4851 - val_accuracy: 0.7775 - lr: 1.0000e-04
# Epoch 57/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9670 - mean_io_u: 0.4852 - accuracy: 0.7907
# Epoch 00057: val_accuracy did not improve from 0.77894
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9670 - mean_io_u: 0.4852 - accuracy: 0.7907 - val_loss: 1.1005 - val_mean_io_u: 0.4852 - val_accuracy: 0.7680 - lr: 1.0000e-04
# Epoch 58/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9643 - mean_io_u: 0.4852 - accuracy: 0.7900
# Epoch 00058: val_accuracy did not improve from 0.77894
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9643 - mean_io_u: 0.4852 - accuracy: 0.7900 - val_loss: 1.1572 - val_mean_io_u: 0.4850 - val_accuracy: 0.7594 - lr: 1.0000e-04
# Epoch 59/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9442 - mean_io_u: 0.4852 - accuracy: 0.7925
# Epoch 00059: val_accuracy did not improve from 0.77894
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9442 - mean_io_u: 0.4852 - accuracy: 0.7925 - val_loss: 1.0101 - val_mean_io_u: 0.4854 - val_accuracy: 0.7682 - lr: 1.0000e-04
# Epoch 60/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9521 - mean_io_u: 0.4852 - accuracy: 0.7889
# Epoch 00060: val_accuracy improved from 0.77894 to 0.78636, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.9521 - mean_io_u: 0.4852 - accuracy: 0.7889 - val_loss: 0.9178 - val_mean_io_u: 0.4855 - val_accuracy: 0.7864 - lr: 1.0000e-04
# Epoch 61/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.4852 - accuracy: 0.7930
# Epoch 00061: val_accuracy did not improve from 0.78636
# 45/45 [==============================] - 13s 289ms/step - loss: 0.9247 - mean_io_u: 0.4852 - accuracy: 0.7930 - val_loss: 1.0285 - val_mean_io_u: 0.4851 - val_accuracy: 0.7746 - lr: 1.0000e-04
# Epoch 62/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9231 - mean_io_u: 0.4852 - accuracy: 0.7912
# Epoch 00062: val_accuracy did not improve from 0.78636
# 45/45 [==============================] - 13s 293ms/step - loss: 0.9231 - mean_io_u: 0.4852 - accuracy: 0.7912 - val_loss: 1.0950 - val_mean_io_u: 0.4851 - val_accuracy: 0.7610 - lr: 1.0000e-04
# Epoch 63/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9081 - mean_io_u: 0.4852 - accuracy: 0.7935
# Epoch 00063: val_accuracy improved from 0.78636 to 0.78790, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.9081 - mean_io_u: 0.4852 - accuracy: 0.7935 - val_loss: 1.0046 - val_mean_io_u: 0.4851 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 64/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9000 - mean_io_u: 0.4852 - accuracy: 0.7940
# Epoch 00064: val_accuracy did not improve from 0.78790
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9000 - mean_io_u: 0.4852 - accuracy: 0.7940 - val_loss: 1.2456 - val_mean_io_u: 0.4848 - val_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 65/200
# 45/45 [==============================] - ETA: 0s - loss: 0.9020 - mean_io_u: 0.4852 - accuracy: 0.7916
# Epoch 00065: val_accuracy did not improve from 0.78790
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9020 - mean_io_u: 0.4852 - accuracy: 0.7916 - val_loss: 0.9935 - val_mean_io_u: 0.4855 - val_accuracy: 0.7533 - lr: 1.0000e-04
# Epoch 66/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8895 - mean_io_u: 0.4852 - accuracy: 0.7923
# Epoch 00066: val_accuracy did not improve from 0.78790
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8895 - mean_io_u: 0.4852 - accuracy: 0.7923 - val_loss: 1.0477 - val_mean_io_u: 0.4851 - val_accuracy: 0.7653 - lr: 1.0000e-04
# Epoch 67/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8923 - mean_io_u: 0.4852 - accuracy: 0.7912
# Epoch 00067: val_accuracy improved from 0.78790 to 0.79508, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 293ms/step - loss: 0.8923 - mean_io_u: 0.4852 - accuracy: 0.7912 - val_loss: 0.9153 - val_mean_io_u: 0.4851 - val_accuracy: 0.7951 - lr: 1.0000e-04
# Epoch 68/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8749 - mean_io_u: 0.4852 - accuracy: 0.7922
# Epoch 00068: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 288ms/step - loss: 0.8749 - mean_io_u: 0.4852 - accuracy: 0.7922 - val_loss: 1.1593 - val_mean_io_u: 0.4851 - val_accuracy: 0.7298 - lr: 1.0000e-04
# Epoch 69/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8687 - mean_io_u: 0.4852 - accuracy: 0.7936
# Epoch 00069: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 291ms/step - loss: 0.8687 - mean_io_u: 0.4852 - accuracy: 0.7936 - val_loss: 0.9122 - val_mean_io_u: 0.4854 - val_accuracy: 0.7808 - lr: 1.0000e-04
# Epoch 70/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8491 - mean_io_u: 0.4852 - accuracy: 0.7943
# Epoch 00070: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8491 - mean_io_u: 0.4852 - accuracy: 0.7943 - val_loss: 0.9389 - val_mean_io_u: 0.4852 - val_accuracy: 0.7706 - lr: 1.0000e-04
# Epoch 71/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8595 - mean_io_u: 0.4852 - accuracy: 0.7919
# Epoch 00071: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8595 - mean_io_u: 0.4852 - accuracy: 0.7919 - val_loss: 0.9364 - val_mean_io_u: 0.4852 - val_accuracy: 0.7825 - lr: 1.0000e-04
# Epoch 72/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8468 - mean_io_u: 0.4852 - accuracy: 0.7937
# Epoch 00072: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8468 - mean_io_u: 0.4852 - accuracy: 0.7937 - val_loss: 0.9157 - val_mean_io_u: 0.4851 - val_accuracy: 0.7757 - lr: 1.0000e-04
# Epoch 73/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8395 - mean_io_u: 0.4852 - accuracy: 0.7941
# Epoch 00073: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8395 - mean_io_u: 0.4852 - accuracy: 0.7941 - val_loss: 0.8926 - val_mean_io_u: 0.4856 - val_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 74/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8342 - mean_io_u: 0.4852 - accuracy: 0.7937
# Epoch 00074: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 288ms/step - loss: 0.8342 - mean_io_u: 0.4852 - accuracy: 0.7937 - val_loss: 1.0777 - val_mean_io_u: 0.4848 - val_accuracy: 0.7620 - lr: 1.0000e-04
# Epoch 75/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8374 - mean_io_u: 0.4852 - accuracy: 0.7918
# Epoch 00075: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 288ms/step - loss: 0.8374 - mean_io_u: 0.4852 - accuracy: 0.7918 - val_loss: 0.9743 - val_mean_io_u: 0.4853 - val_accuracy: 0.7591 - lr: 1.0000e-04
# Epoch 76/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8258 - mean_io_u: 0.4852 - accuracy: 0.7938
# Epoch 00076: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8258 - mean_io_u: 0.4852 - accuracy: 0.7938 - val_loss: 0.9548 - val_mean_io_u: 0.4852 - val_accuracy: 0.7687 - lr: 1.0000e-04
# Epoch 77/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8236 - mean_io_u: 0.4852 - accuracy: 0.7931
# Epoch 00077: val_accuracy did not improve from 0.79508
# 45/45 [==============================] - 13s 287ms/step - loss: 0.8236 - mean_io_u: 0.4852 - accuracy: 0.7931 - val_loss: 0.8836 - val_mean_io_u: 0.4854 - val_accuracy: 0.7829 - lr: 1.0000e-04
# Epoch 78/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8061 - mean_io_u: 0.4853 - accuracy: 0.7945
# Epoch 00078: val_accuracy improved from 0.79508 to 0.80137, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.8061 - mean_io_u: 0.4853 - accuracy: 0.7945 - val_loss: 0.8319 - val_mean_io_u: 0.4853 - val_accuracy: 0.8014 - lr: 1.0000e-04
# Epoch 79/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8113 - mean_io_u: 0.4852 - accuracy: 0.7945
# Epoch 00079: val_accuracy did not improve from 0.80137
# 45/45 [==============================] - 13s 286ms/step - loss: 0.8113 - mean_io_u: 0.4852 - accuracy: 0.7945 - val_loss: 0.9037 - val_mean_io_u: 0.4852 - val_accuracy: 0.7769 - lr: 1.0000e-04
# Epoch 80/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8073 - mean_io_u: 0.4852 - accuracy: 0.7948
# Epoch 00080: val_accuracy did not improve from 0.80137
# 45/45 [==============================] - 13s 286ms/step - loss: 0.8073 - mean_io_u: 0.4852 - accuracy: 0.7948 - val_loss: 1.0246 - val_mean_io_u: 0.4847 - val_accuracy: 0.7717 - lr: 1.0000e-04
# Epoch 81/200
# 45/45 [==============================] - ETA: 0s - loss: 0.8057 - mean_io_u: 0.4852 - accuracy: 0.7952
# Epoch 00081: val_accuracy did not improve from 0.80137
# 45/45 [==============================] - 13s 286ms/step - loss: 0.8057 - mean_io_u: 0.4852 - accuracy: 0.7952 - val_loss: 0.8785 - val_mean_io_u: 0.4852 - val_accuracy: 0.7887 - lr: 1.0000e-04
# Epoch 82/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7943 - mean_io_u: 0.4852 - accuracy: 0.7959
# Epoch 00082: val_accuracy did not improve from 0.80137
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7943 - mean_io_u: 0.4852 - accuracy: 0.7959 - val_loss: 0.9410 - val_mean_io_u: 0.4850 - val_accuracy: 0.7799 - lr: 1.0000e-04
# Epoch 83/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7868 - mean_io_u: 0.4853 - accuracy: 0.7988
# Epoch 00083: val_accuracy improved from 0.80137 to 0.80493, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 293ms/step - loss: 0.7868 - mean_io_u: 0.4853 - accuracy: 0.7988 - val_loss: 0.7602 - val_mean_io_u: 0.4855 - val_accuracy: 0.8049 - lr: 1.0000e-04
# Epoch 84/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7848 - mean_io_u: 0.4852 - accuracy: 0.7963
# Epoch 00084: val_accuracy did not improve from 0.80493
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7848 - mean_io_u: 0.4852 - accuracy: 0.7963 - val_loss: 0.9005 - val_mean_io_u: 0.4852 - val_accuracy: 0.7754 - lr: 1.0000e-04
# Epoch 85/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7680 - mean_io_u: 0.4852 - accuracy: 0.8047
# Epoch 00085: val_accuracy improved from 0.80493 to 0.80933, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.7680 - mean_io_u: 0.4852 - accuracy: 0.8047 - val_loss: 0.8119 - val_mean_io_u: 0.4851 - val_accuracy: 0.8093 - lr: 1.0000e-04
# Epoch 86/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7788 - mean_io_u: 0.4852 - accuracy: 0.8017
# Epoch 00086: val_accuracy did not improve from 0.80933
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7788 - mean_io_u: 0.4852 - accuracy: 0.8017 - val_loss: 0.8211 - val_mean_io_u: 0.4852 - val_accuracy: 0.8064 - lr: 1.0000e-04
# Epoch 87/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7656 - mean_io_u: 0.4852 - accuracy: 0.8031
# Epoch 00087: val_accuracy improved from 0.80933 to 0.80968, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 298ms/step - loss: 0.7656 - mean_io_u: 0.4852 - accuracy: 0.8031 - val_loss: 0.8178 - val_mean_io_u: 0.4851 - val_accuracy: 0.8097 - lr: 1.0000e-04
# Epoch 88/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7645 - mean_io_u: 0.4852 - accuracy: 0.8056
# Epoch 00088: val_accuracy did not improve from 0.80968
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7645 - mean_io_u: 0.4852 - accuracy: 0.8056 - val_loss: 0.9072 - val_mean_io_u: 0.4848 - val_accuracy: 0.7935 - lr: 1.0000e-04
# Epoch 89/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7686 - mean_io_u: 0.4852 - accuracy: 0.8023
# Epoch 00089: val_accuracy did not improve from 0.80968
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7686 - mean_io_u: 0.4852 - accuracy: 0.8023 - val_loss: 0.8025 - val_mean_io_u: 0.4854 - val_accuracy: 0.7954 - lr: 1.0000e-04
# Epoch 90/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7557 - mean_io_u: 0.4852 - accuracy: 0.8068
# Epoch 00090: val_accuracy did not improve from 0.80968
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7557 - mean_io_u: 0.4852 - accuracy: 0.8068 - val_loss: 0.9362 - val_mean_io_u: 0.4848 - val_accuracy: 0.7915 - lr: 1.0000e-04
# Epoch 91/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7556 - mean_io_u: 0.4852 - accuracy: 0.8048
# Epoch 00091: val_accuracy did not improve from 0.80968
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7556 - mean_io_u: 0.4852 - accuracy: 0.8048 - val_loss: 0.8637 - val_mean_io_u: 0.4851 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 92/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7465 - mean_io_u: 0.4852 - accuracy: 0.8084
# Epoch 00092: val_accuracy did not improve from 0.80968
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7465 - mean_io_u: 0.4852 - accuracy: 0.8084 - val_loss: 0.9253 - val_mean_io_u: 0.4851 - val_accuracy: 0.7773 - lr: 1.0000e-04
# Epoch 93/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7556 - mean_io_u: 0.4852 - accuracy: 0.8052
# Epoch 00093: val_accuracy improved from 0.80968 to 0.81759, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 292ms/step - loss: 0.7556 - mean_io_u: 0.4852 - accuracy: 0.8052 - val_loss: 0.6560 - val_mean_io_u: 0.4856 - val_accuracy: 0.8176 - lr: 1.0000e-04
# Epoch 94/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7401 - mean_io_u: 0.4852 - accuracy: 0.8108
# Epoch 00094: val_accuracy did not improve from 0.81759
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7401 - mean_io_u: 0.4852 - accuracy: 0.8108 - val_loss: 0.8737 - val_mean_io_u: 0.4851 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 95/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7434 - mean_io_u: 0.4852 - accuracy: 0.8066
# Epoch 00095: val_accuracy did not improve from 0.81759
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7434 - mean_io_u: 0.4852 - accuracy: 0.8066 - val_loss: 0.8278 - val_mean_io_u: 0.4849 - val_accuracy: 0.8033 - lr: 1.0000e-04
# Epoch 96/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7418 - mean_io_u: 0.4852 - accuracy: 0.8071
# Epoch 00096: val_accuracy did not improve from 0.81759
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7418 - mean_io_u: 0.4852 - accuracy: 0.8071 - val_loss: 0.8057 - val_mean_io_u: 0.4851 - val_accuracy: 0.8135 - lr: 1.0000e-04
# Epoch 97/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7290 - mean_io_u: 0.4852 - accuracy: 0.8071
# Epoch 00097: val_accuracy improved from 0.81759 to 0.82154, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 293ms/step - loss: 0.7290 - mean_io_u: 0.4852 - accuracy: 0.8071 - val_loss: 0.7140 - val_mean_io_u: 0.4852 - val_accuracy: 0.8215 - lr: 1.0000e-04
# Epoch 98/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7196 - mean_io_u: 0.4852 - accuracy: 0.8124
# Epoch 00098: val_accuracy did not improve from 0.82154
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7196 - mean_io_u: 0.4852 - accuracy: 0.8124 - val_loss: 0.9525 - val_mean_io_u: 0.4851 - val_accuracy: 0.7788 - lr: 1.0000e-04
# Epoch 99/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7128 - mean_io_u: 0.4852 - accuracy: 0.8138
# Epoch 00099: val_accuracy did not improve from 0.82154
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7128 - mean_io_u: 0.4852 - accuracy: 0.8138 - val_loss: 0.7002 - val_mean_io_u: 0.4852 - val_accuracy: 0.8197 - lr: 1.0000e-04
# Epoch 100/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7191 - mean_io_u: 0.4852 - accuracy: 0.8110
# Epoch 00100: val_accuracy did not improve from 0.82154
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7191 - mean_io_u: 0.4852 - accuracy: 0.8110 - val_loss: 0.9435 - val_mean_io_u: 0.4850 - val_accuracy: 0.7784 - lr: 1.0000e-04
# Epoch 101/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7280 - mean_io_u: 0.4852 - accuracy: 0.8079
# Epoch 00101: val_accuracy did not improve from 0.82154
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7280 - mean_io_u: 0.4852 - accuracy: 0.8079 - val_loss: 0.7824 - val_mean_io_u: 0.4852 - val_accuracy: 0.8127 - lr: 1.0000e-04
# Epoch 102/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8112
# Epoch 00102: val_accuracy improved from 0.82154 to 0.82254, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 293ms/step - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8112 - val_loss: 0.7297 - val_mean_io_u: 0.4853 - val_accuracy: 0.8225 - lr: 1.0000e-04
# Epoch 103/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8099
# Epoch 00103: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8099 - val_loss: 0.7904 - val_mean_io_u: 0.4851 - val_accuracy: 0.8085 - lr: 1.0000e-04
# Epoch 104/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7058 - mean_io_u: 0.4852 - accuracy: 0.8125
# Epoch 00104: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7058 - mean_io_u: 0.4852 - accuracy: 0.8125 - val_loss: 0.7161 - val_mean_io_u: 0.4853 - val_accuracy: 0.8176 - lr: 1.0000e-04
# Epoch 105/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7062 - mean_io_u: 0.4852 - accuracy: 0.8088
# Epoch 00105: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7062 - mean_io_u: 0.4852 - accuracy: 0.8088 - val_loss: 0.8689 - val_mean_io_u: 0.4851 - val_accuracy: 0.7910 - lr: 1.0000e-04
# Epoch 106/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7087 - mean_io_u: 0.4852 - accuracy: 0.8084
# Epoch 00106: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7087 - mean_io_u: 0.4852 - accuracy: 0.8084 - val_loss: 0.8202 - val_mean_io_u: 0.4851 - val_accuracy: 0.8026 - lr: 1.0000e-04
# Epoch 107/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6976 - mean_io_u: 0.4852 - accuracy: 0.8125
# Epoch 00107: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6976 - mean_io_u: 0.4852 - accuracy: 0.8125 - val_loss: 0.8656 - val_mean_io_u: 0.4850 - val_accuracy: 0.7891 - lr: 1.0000e-04
# Epoch 108/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7073 - mean_io_u: 0.4852 - accuracy: 0.8083
# Epoch 00108: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7073 - mean_io_u: 0.4852 - accuracy: 0.8083 - val_loss: 0.7313 - val_mean_io_u: 0.4855 - val_accuracy: 0.8082 - lr: 1.0000e-04
# Epoch 109/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7018 - mean_io_u: 0.4852 - accuracy: 0.8118
# Epoch 00109: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7018 - mean_io_u: 0.4852 - accuracy: 0.8118 - val_loss: 0.9031 - val_mean_io_u: 0.4852 - val_accuracy: 0.7698 - lr: 1.0000e-04
# Epoch 110/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6978 - mean_io_u: 0.4853 - accuracy: 0.8085
# Epoch 00110: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6978 - mean_io_u: 0.4853 - accuracy: 0.8085 - val_loss: 0.8574 - val_mean_io_u: 0.4852 - val_accuracy: 0.7779 - lr: 1.0000e-04
# Epoch 111/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7013 - mean_io_u: 0.4852 - accuracy: 0.8094
# Epoch 00111: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 285ms/step - loss: 0.7013 - mean_io_u: 0.4852 - accuracy: 0.8094 - val_loss: 0.8490 - val_mean_io_u: 0.4852 - val_accuracy: 0.7840 - lr: 1.0000e-04
# Epoch 112/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7008 - mean_io_u: 0.4852 - accuracy: 0.8093
# Epoch 00112: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7008 - mean_io_u: 0.4852 - accuracy: 0.8093 - val_loss: 0.9200 - val_mean_io_u: 0.4851 - val_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 113/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6921 - mean_io_u: 0.4852 - accuracy: 0.8116
# Epoch 00113: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6921 - mean_io_u: 0.4852 - accuracy: 0.8116 - val_loss: 0.8558 - val_mean_io_u: 0.4851 - val_accuracy: 0.7844 - lr: 1.0000e-04
# Epoch 114/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6978 - mean_io_u: 0.4852 - accuracy: 0.8100
# Epoch 00114: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6978 - mean_io_u: 0.4852 - accuracy: 0.8100 - val_loss: 0.7602 - val_mean_io_u: 0.4855 - val_accuracy: 0.7984 - lr: 1.0000e-04
# Epoch 115/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8067
# Epoch 00115: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7103 - mean_io_u: 0.4852 - accuracy: 0.8067 - val_loss: 0.9043 - val_mean_io_u: 0.4850 - val_accuracy: 0.7766 - lr: 1.0000e-04
# Epoch 116/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6905 - mean_io_u: 0.4852 - accuracy: 0.8133
# Epoch 00116: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6905 - mean_io_u: 0.4852 - accuracy: 0.8133 - val_loss: 0.8513 - val_mean_io_u: 0.4851 - val_accuracy: 0.7886 - lr: 1.0000e-04
# Epoch 117/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6944 - mean_io_u: 0.4852 - accuracy: 0.8088
# Epoch 00117: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6944 - mean_io_u: 0.4852 - accuracy: 0.8088 - val_loss: 0.6647 - val_mean_io_u: 0.4855 - val_accuracy: 0.8203 - lr: 1.0000e-04
# Epoch 118/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7050 - mean_io_u: 0.4852 - accuracy: 0.8058
# Epoch 00118: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7050 - mean_io_u: 0.4852 - accuracy: 0.8058 - val_loss: 0.8559 - val_mean_io_u: 0.4849 - val_accuracy: 0.7813 - lr: 1.0000e-04
# Epoch 119/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6945 - mean_io_u: 0.4853 - accuracy: 0.8097
# Epoch 00119: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6945 - mean_io_u: 0.4853 - accuracy: 0.8097 - val_loss: 0.8345 - val_mean_io_u: 0.4855 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 120/200
# 45/45 [==============================] - ETA: 0s - loss: 0.7012 - mean_io_u: 0.4852 - accuracy: 0.8106
# Epoch 00120: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7012 - mean_io_u: 0.4852 - accuracy: 0.8106 - val_loss: 1.0131 - val_mean_io_u: 0.4849 - val_accuracy: 0.7601 - lr: 1.0000e-04
# Epoch 121/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6947 - mean_io_u: 0.4852 - accuracy: 0.8090
# Epoch 00121: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6947 - mean_io_u: 0.4852 - accuracy: 0.8090 - val_loss: 0.8313 - val_mean_io_u: 0.4852 - val_accuracy: 0.7945 - lr: 1.0000e-04
# Epoch 122/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6929 - mean_io_u: 0.4852 - accuracy: 0.8070
# Epoch 00122: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6929 - mean_io_u: 0.4852 - accuracy: 0.8070 - val_loss: 0.7832 - val_mean_io_u: 0.4851 - val_accuracy: 0.7987 - lr: 1.0000e-04
# Epoch 123/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6946 - mean_io_u: 0.4852 - accuracy: 0.8077
# Epoch 00123: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6946 - mean_io_u: 0.4852 - accuracy: 0.8077 - val_loss: 0.8505 - val_mean_io_u: 0.4849 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 124/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6923 - mean_io_u: 0.4852 - accuracy: 0.8098
# Epoch 00124: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6923 - mean_io_u: 0.4852 - accuracy: 0.8098 - val_loss: 0.8766 - val_mean_io_u: 0.4852 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 125/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6876 - mean_io_u: 0.4852 - accuracy: 0.8077
# Epoch 00125: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6876 - mean_io_u: 0.4852 - accuracy: 0.8077 - val_loss: 0.7720 - val_mean_io_u: 0.4855 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 126/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6929 - mean_io_u: 0.4852 - accuracy: 0.8072
# Epoch 00126: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6929 - mean_io_u: 0.4852 - accuracy: 0.8072 - val_loss: 0.8825 - val_mean_io_u: 0.4851 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 127/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6970 - mean_io_u: 0.4852 - accuracy: 0.8084
# Epoch 00127: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6970 - mean_io_u: 0.4852 - accuracy: 0.8084 - val_loss: 0.8376 - val_mean_io_u: 0.4850 - val_accuracy: 0.7965 - lr: 1.0000e-04
# Epoch 128/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6911 - mean_io_u: 0.4852 - accuracy: 0.8071
# Epoch 00128: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6911 - mean_io_u: 0.4852 - accuracy: 0.8071 - val_loss: 0.9150 - val_mean_io_u: 0.4850 - val_accuracy: 0.7827 - lr: 1.0000e-04
# Epoch 129/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6827 - mean_io_u: 0.4852 - accuracy: 0.8081
# Epoch 00129: val_accuracy did not improve from 0.82254
# ...
# Epoch 158/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6678 - mean_io_u: 0.4852 - accuracy: 0.8124
# Epoch 00158: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6678 - mean_io_u: 0.4852 - accuracy: 0.8124 - val_loss: 0.7885 - val_mean_io_u: 0.4852 - val_accuracy: 0.8094 - lr: 5.0000e-05
# Epoch 159/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6628 - mean_io_u: 0.4852 - accuracy: 0.8114
# Epoch 00159: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6628 - mean_io_u: 0.4852 - accuracy: 0.8114 - val_loss: 0.6899 - val_mean_io_u: 0.4853 - val_accuracy: 0.8060 - lr: 5.0000e-05
# Epoch 160/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6660 - mean_io_u: 0.4852 - accuracy: 0.8125
# Epoch 00160: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6660 - mean_io_u: 0.4852 - accuracy: 0.8125 - val_loss: 0.8660 - val_mean_io_u: 0.4851 - val_accuracy: 0.7872 - lr: 5.0000e-05
# Epoch 161/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6650 - mean_io_u: 0.4852 - accuracy: 0.8109
# Epoch 00161: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6650 - mean_io_u: 0.4852 - accuracy: 0.8109 - val_loss: 0.8025 - val_mean_io_u: 0.4851 - val_accuracy: 0.7979 - lr: 5.0000e-05
# Epoch 162/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6651 - mean_io_u: 0.4852 - accuracy: 0.8108
# Epoch 00162: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6651 - mean_io_u: 0.4852 - accuracy: 0.8108 - val_loss: 0.6589 - val_mean_io_u: 0.4856 - val_accuracy: 0.8153 - lr: 5.0000e-05
# Epoch 163/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6648 - mean_io_u: 0.4852 - accuracy: 0.8103
# Epoch 00163: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6648 - mean_io_u: 0.4852 - accuracy: 0.8103 - val_loss: 0.8546 - val_mean_io_u: 0.4851 - val_accuracy: 0.7972 - lr: 5.0000e-05
# Epoch 164/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6624 - mean_io_u: 0.4852 - accuracy: 0.8146
# Epoch 00164: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6624 - mean_io_u: 0.4852 - accuracy: 0.8146 - val_loss: 0.8685 - val_mean_io_u: 0.4848 - val_accuracy: 0.7895 - lr: 5.0000e-05
# Epoch 165/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6670 - mean_io_u: 0.4852 - accuracy: 0.8135
# Epoch 00165: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6670 - mean_io_u: 0.4852 - accuracy: 0.8135 - val_loss: 0.8090 - val_mean_io_u: 0.4851 - val_accuracy: 0.7984 - lr: 5.0000e-05
# Epoch 166/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6554 - mean_io_u: 0.4852 - accuracy: 0.8165
# Epoch 00166: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6554 - mean_io_u: 0.4852 - accuracy: 0.8165 - val_loss: 0.7670 - val_mean_io_u: 0.4852 - val_accuracy: 0.8123 - lr: 5.0000e-05
# Epoch 167/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6756 - mean_io_u: 0.4852 - accuracy: 0.8071
# Epoch 00167: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6756 - mean_io_u: 0.4852 - accuracy: 0.8071 - val_loss: 0.8092 - val_mean_io_u: 0.4852 - val_accuracy: 0.8048 - lr: 5.0000e-05
# Epoch 168/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6565 - mean_io_u: 0.4852 - accuracy: 0.8166
# Epoch 00168: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6565 - mean_io_u: 0.4852 - accuracy: 0.8166 - val_loss: 0.7665 - val_mean_io_u: 0.4852 - val_accuracy: 0.8092 - lr: 5.0000e-05
# Epoch 169/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6629 - mean_io_u: 0.4852 - accuracy: 0.8134
# Epoch 00169: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6629 - mean_io_u: 0.4852 - accuracy: 0.8134 - val_loss: 0.8849 - val_mean_io_u: 0.4848 - val_accuracy: 0.7959 - lr: 5.0000e-05
# Epoch 170/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6583 - mean_io_u: 0.4852 - accuracy: 0.8122
# Epoch 00170: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6583 - mean_io_u: 0.4852 - accuracy: 0.8122 - val_loss: 0.7712 - val_mean_io_u: 0.4852 - val_accuracy: 0.7976 - lr: 5.0000e-05
# Epoch 171/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6597 - mean_io_u: 0.4852 - accuracy: 0.8134
# Epoch 00171: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6597 - mean_io_u: 0.4852 - accuracy: 0.8134 - val_loss: 0.7934 - val_mean_io_u: 0.4852 - val_accuracy: 0.8036 - lr: 5.0000e-05
# Epoch 172/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6712 - mean_io_u: 0.4852 - accuracy: 0.8109
# Epoch 00172: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6712 - mean_io_u: 0.4852 - accuracy: 0.8109 - val_loss: 0.7740 - val_mean_io_u: 0.4852 - val_accuracy: 0.8061 - lr: 5.0000e-05
# Epoch 173/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6574 - mean_io_u: 0.4853 - accuracy: 0.8139
# Epoch 00173: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6574 - mean_io_u: 0.4853 - accuracy: 0.8139 - val_loss: 0.9374 - val_mean_io_u: 0.4848 - val_accuracy: 0.7866 - lr: 5.0000e-05
# Epoch 174/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6662 - mean_io_u: 0.4852 - accuracy: 0.8184
# Epoch 00174: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6662 - mean_io_u: 0.4852 - accuracy: 0.8184 - val_loss: 0.7947 - val_mean_io_u: 0.4852 - val_accuracy: 0.8066 - lr: 5.0000e-05
# Epoch 175/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6632 - mean_io_u: 0.4852 - accuracy: 0.8138
# Epoch 00175: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6632 - mean_io_u: 0.4852 - accuracy: 0.8138 - val_loss: 0.8182 - val_mean_io_u: 0.4851 - val_accuracy: 0.7995 - lr: 5.0000e-05
# Epoch 176/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6596 - mean_io_u: 0.4852 - accuracy: 0.8118
# Epoch 00176: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6596 - mean_io_u: 0.4852 - accuracy: 0.8118 - val_loss: 0.7942 - val_mean_io_u: 0.4852 - val_accuracy: 0.8010 - lr: 5.0000e-05
# Epoch 177/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6610 - mean_io_u: 0.4852 - accuracy: 0.8127
# Epoch 00177: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6610 - mean_io_u: 0.4852 - accuracy: 0.8127 - val_loss: 0.8750 - val_mean_io_u: 0.4851 - val_accuracy: 0.7942 - lr: 5.0000e-05
# Epoch 178/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6606 - mean_io_u: 0.4852 - accuracy: 0.8100
# Epoch 00178: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6606 - mean_io_u: 0.4852 - accuracy: 0.8100 - val_loss: 0.7261 - val_mean_io_u: 0.4851 - val_accuracy: 0.8137 - lr: 5.0000e-05
# Epoch 179/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6612 - mean_io_u: 0.4852 - accuracy: 0.8109
# Epoch 00179: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6612 - mean_io_u: 0.4852 - accuracy: 0.8109 - val_loss: 0.7290 - val_mean_io_u: 0.4852 - val_accuracy: 0.8090 - lr: 5.0000e-05
# Epoch 180/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6628 - mean_io_u: 0.4852 - accuracy: 0.8105
# Epoch 00180: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6628 - mean_io_u: 0.4852 - accuracy: 0.8105 - val_loss: 0.7749 - val_mean_io_u: 0.4851 - val_accuracy: 0.8028 - lr: 5.0000e-05
# Epoch 181/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6583 - mean_io_u: 0.4853 - accuracy: 0.8097
# Epoch 00181: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6583 - mean_io_u: 0.4853 - accuracy: 0.8097 - val_loss: 0.7578 - val_mean_io_u: 0.4852 - val_accuracy: 0.8059 - lr: 5.0000e-05
# Epoch 182/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6534 - mean_io_u: 0.4852 - accuracy: 0.8139
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00182: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6534 - mean_io_u: 0.4852 - accuracy: 0.8139 - val_loss: 0.7467 - val_mean_io_u: 0.4853 - val_accuracy: 0.8136 - lr: 5.0000e-05
# Epoch 183/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6588 - mean_io_u: 0.4852 - accuracy: 0.8141
# Epoch 00183: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6588 - mean_io_u: 0.4852 - accuracy: 0.8141 - val_loss: 0.8917 - val_mean_io_u: 0.4850 - val_accuracy: 0.7907 - lr: 2.5000e-05
# Epoch 184/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6617 - mean_io_u: 0.4852 - accuracy: 0.8145
# Epoch 00184: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6617 - mean_io_u: 0.4852 - accuracy: 0.8145 - val_loss: 0.7066 - val_mean_io_u: 0.4852 - val_accuracy: 0.8154 - lr: 2.5000e-05
# Epoch 185/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6591 - mean_io_u: 0.4852 - accuracy: 0.8123
# Epoch 00185: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6591 - mean_io_u: 0.4852 - accuracy: 0.8123 - val_loss: 0.8455 - val_mean_io_u: 0.4849 - val_accuracy: 0.7948 - lr: 2.5000e-05
# Epoch 186/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6607 - mean_io_u: 0.4852 - accuracy: 0.8137
# Epoch 00186: val_accuracy did not improve from 0.82254
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6607 - mean_io_u: 0.4852 - accuracy: 0.8137 - val_loss: 0.7792 - val_mean_io_u: 0.4851 - val_accuracy: 0.8018 - lr: 2.5000e-05
# Epoch 187/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6557 - mean_io_u: 0.4852 - accuracy: 0.8156
# Epoch 00187: val_accuracy improved from 0.82254 to 0.82809, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 294ms/step - loss: 0.6557 - mean_io_u: 0.4852 - accuracy: 0.8156 - val_loss: 0.6625 - val_mean_io_u: 0.4854 - val_accuracy: 0.8281 - lr: 2.5000e-05
# Epoch 188/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6508 - mean_io_u: 0.4853 - accuracy: 0.8175
# Epoch 00188: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6508 - mean_io_u: 0.4853 - accuracy: 0.8175 - val_loss: 0.6880 - val_mean_io_u: 0.4855 - val_accuracy: 0.8074 - lr: 2.5000e-05
# Epoch 189/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6612 - mean_io_u: 0.4852 - accuracy: 0.8129
# Epoch 00189: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6612 - mean_io_u: 0.4852 - accuracy: 0.8129 - val_loss: 0.8729 - val_mean_io_u: 0.4848 - val_accuracy: 0.7889 - lr: 2.5000e-05
# Epoch 190/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6639 - mean_io_u: 0.4852 - accuracy: 0.8150
# Epoch 00190: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6639 - mean_io_u: 0.4852 - accuracy: 0.8150 - val_loss: 0.7380 - val_mean_io_u: 0.4853 - val_accuracy: 0.8099 - lr: 2.5000e-05
# Epoch 191/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6533 - mean_io_u: 0.4852 - accuracy: 0.8119
# Epoch 00191: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6533 - mean_io_u: 0.4852 - accuracy: 0.8119 - val_loss: 0.7713 - val_mean_io_u: 0.4852 - val_accuracy: 0.8105 - lr: 2.5000e-05
# Epoch 192/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6524 - mean_io_u: 0.4852 - accuracy: 0.8151
# Epoch 00192: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6524 - mean_io_u: 0.4852 - accuracy: 0.8151 - val_loss: 0.7820 - val_mean_io_u: 0.4852 - val_accuracy: 0.7996 - lr: 2.5000e-05
# Epoch 193/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6508 - mean_io_u: 0.4852 - accuracy: 0.8153
# Epoch 00193: val_accuracy did not improve from 0.82809
# 45/45 [==============================] - 13s 294ms/step - loss: 0.6508 - mean_io_u: 0.4852 - accuracy: 0.8153 - val_loss: 0.8502 - val_mean_io_u: 0.4852 - val_accuracy: 0.7974 - lr: 2.5000e-05
# Epoch 194/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6556 - mean_io_u: 0.4852 - accuracy: 0.8148
# Epoch 00194: val_accuracy improved from 0.82809 to 0.83179, saving model to MobileUnet.hdf5
# 45/45 [==============================] - 13s 299ms/step - loss: 0.6556 - mean_io_u: 0.4852 - accuracy: 0.8148 - val_loss: 0.6062 - val_mean_io_u: 0.4855 - val_accuracy: 0.8318 - lr: 2.5000e-05
# Epoch 195/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6600 - mean_io_u: 0.4853 - accuracy: 0.8148
# Epoch 00195: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 292ms/step - loss: 0.6600 - mean_io_u: 0.4853 - accuracy: 0.8148 - val_loss: 0.7938 - val_mean_io_u: 0.4852 - val_accuracy: 0.8056 - lr: 2.5000e-05
# Epoch 196/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6515 - mean_io_u: 0.4852 - accuracy: 0.8168
# Epoch 00196: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6515 - mean_io_u: 0.4852 - accuracy: 0.8168 - val_loss: 0.7795 - val_mean_io_u: 0.4851 - val_accuracy: 0.8111 - lr: 2.5000e-05
# Epoch 197/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6549 - mean_io_u: 0.4852 - accuracy: 0.8126
# Epoch 00197: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 292ms/step - loss: 0.6549 - mean_io_u: 0.4852 - accuracy: 0.8126 - val_loss: 0.7371 - val_mean_io_u: 0.4852 - val_accuracy: 0.8201 - lr: 2.5000e-05
# Epoch 198/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6580 - mean_io_u: 0.4852 - accuracy: 0.8125
# Epoch 00198: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6580 - mean_io_u: 0.4852 - accuracy: 0.8125 - val_loss: 0.7354 - val_mean_io_u: 0.4852 - val_accuracy: 0.8158 - lr: 2.5000e-05
# Epoch 199/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6665 - mean_io_u: 0.4852 - accuracy: 0.8141
# Epoch 00199: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6665 - mean_io_u: 0.4852 - accuracy: 0.8141 - val_loss: 0.8576 - val_mean_io_u: 0.4850 - val_accuracy: 0.7927 - lr: 2.5000e-05
# Epoch 200/200
# 45/45 [==============================] - ETA: 0s - loss: 0.6577 - mean_io_u: 0.4852 - accuracy: 0.8109
# Epoch 00200: val_accuracy did not improve from 0.83179
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6577 - mean_io_u: 0.4852 - accuracy: 0.8109 - val_loss: 0.8715 - val_mean_io_u: 0.4850 - val_accuracy: 0.7901 - lr: 2.5000e-05

# %%
from keras.models import load_model


def visualize_seg(img, gt_mask, shape='normal', gt_mode='sparse'):
    plt.figure(1)
  
  # Img
    plt.subplot(113)
    plt.imshow(img)
  
  # Predict
    #model = load_model("MobileUnet.hdf5")
    pred_mask = model.predict(np.expand_dims(img, 0))
    pred_mask = np.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[0]
    if shape=='flat':
        pred_mask = np.reshape(pred_mask, (256,256)) # Reshape only if you use the flat model. O.w. you dont need
  
    rgb_mask = np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(pred_mask, -1))
  
  # Prediction
    plt.subplot(312)
    plt.imshow(rgb_mask)
              
  # GT mask
    if gt_mode == 'ohe':
        gt_img_ohe = np.argmax(gt_mask, axis=-1)
        gt_mask = np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(gt_img_ohe, -1))              
  
    plt.subplot(313)
    plt.imshow((gt_mask).astype(np.uint8))
# Out:
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Mahmoud Montaser\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
img = next(val_image_generator)[0]
gt_img = next(val_mask_generator)[0]
visualize_seg(img, gt_img, gt_mode='sparse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fabedc54b418> in <module>
# ----> 1 img = next(val_image_generator)[0]
#       2 gt_img = next(val_mask_generator)[0]
#       3 visualize_seg(img, gt_img, gt_mode='sparse')
#
# NameError: name 'val_image_generator' is not defined
